# %%
from RAT_env import *
from NashAgent_lib import *
from NashRL import *
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import csv
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-azm3y3ld because the default path (/home/ubuntu/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# Initialize enviroment for the training

# %%
# Parameters for the Multi-RAT Network
user_area_width = 100
ltesn_area_width = 50
n_aps = 81
n_users = 3
n_steps = 100
cqi_dataset = pd.read_csv("cqi_distance.csv")
rssi_dataset = pd.read_csv("rssi_distance.csv")

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

rat_env = Multi_RAT_Network(user_area_width, ltesn_area_width, n_users, n_aps, cqi_dataset, rssi_dataset, n_steps, plot=True)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Train the Nash Agent

# %%
import time
from datetime import date

start = time.time()

str_dt = date.today().strftime("%d%m%Y")
nash_agent, loss_data, last_rats, episode_rewards, best_actions,eps_list= \
    run_Nash_Agent(rat_env, n_steps=100, nash_agent=None, n_episodes=4000,#4000
                    exploration_fraction = 0.8,AN_file_name="Action_Net",
                    VN_file_name="Value_Net",rv_min=1, rv_max=10,
                    path='/pt_files/Nash_DQN/',early_stop=False, early_lim=1000)

print("Total time taken: ")
print(time.time() - start)
# Out:
# Iteration 0 Loss: 636409085952.0 | V_Loss: 636472262656.0 | A_Loss: 636409085952.0
# tensor([13.6224, 14.1244, 14.4992]) tensor([-20.8462,  37.8036,  10.0454])
# Episode 5 terminated after 31 steps
# tensor([16.2757, 16.4383, 18.7183]) tensor([15.6514, 24.5085, 22.3968])
# Episode 9 terminated after 15 steps
# tensor([23.0614, 21.3563, 21.7093]) tensor([25.9896, 23.8040, 32.7663])
# Episode 12 terminated after 6 steps
# tensor([22.6711, 21.0276, 20.8745]) tensor([ 31.8546, -13.7983, -19.5758])
# Episode 13 terminated after 49 steps
# tensor([24.6551, 23.0686, 21.8368]) tensor([23.6588, 32.8999, 21.7620])
# Episode 15 terminated after 4 steps
# tensor([24.3922, 22.4636, 25.2437]) tensor([26.3689, 20.5345, 27.2559])
# Episode 17 terminated after 23 steps
# tensor([22.9288, 21.1803, 21.0298]) tensor([21.2104, 23.9512, 19.1601])
# Episode 19 terminated after 30 steps
# tensor([19.9722, 19.7830, 19.9779]) tensor([19.7166, 20.3308, 20.6887])
# Episode 21 terminated after 26 steps
# tensor([21.6485, 21.8488, 21.9535]) tensor([21.4892, 22.0512, 22.0894])
# Episode 22 terminated after 24 steps
# tensor([18.5272, 21.3077, 18.0538]) tensor([18.8582, 20.7547, 17.8964])
# Episode 23 terminated after 21 steps
# tensor([18.4938, 20.2811, 18.4127]) tensor([19.2540, 20.7608, 19.4849])
# Episode 24 terminated after 25 steps
# tensor([19.5494, 19.1315, 16.6912]) tensor([26.3353, 29.6867, 18.6616])
# Episode 25 terminated after 50 steps
# tensor([15.8076, 15.4009, 16.0564]) tensor([15.9394, 19.5405, 12.0522])
# Episode 26 terminated after 11 steps
# tensor([15.4468, 15.0691, 15.1150]) tensor([25.6969, 17.0271, 15.3736])
# Episode 28 terminated after 61 steps
# tensor([17.1338, 15.6403, 15.3800]) tensor([13.6566, 17.9938, 14.7913])
# Episode 29 terminated after 22 steps
# tensor([15.8388, 17.5004, 14.9904]) tensor([17.2337, 15.7712, 11.2990])
# Episode 30 terminated after 41 steps
# tensor([17.3370, 17.5989, 15.7996]) tensor([11.6261, 25.2651, 12.1842])
# Episode 32 terminated after 23 steps
# tensor([17.9955, 17.9144, 18.2161]) tensor([15.4511, 17.8433, 19.9765])
# Episode 33 terminated after 45 steps
# tensor([17.3175, 18.0538, 19.0451]) tensor([14.7367, 17.9888, 25.8702])
# Episode 35 terminated after 18 steps
# tensor([18.1122, 17.2709, 17.5987]) tensor([24.4734, 27.3796, 35.3982])
# Episode 36 terminated after 70 steps
# tensor([16.9769, 17.3120, 16.9264]) tensor([18.4813,  1.2752, 19.3897])
# Episode 37 terminated after 93 steps
# tensor([17.0751, 16.2252, 16.7448]) tensor([12.6304, 27.9224, 21.6659])
# Episode 38 terminated after 23 steps
# tensor([17.1735, 16.7343, 17.4217]) tensor([17.0171,  8.7599, 20.8499])
# Episode 39 terminated after 27 steps
# tensor([17.0928, 17.5296, 17.4370]) tensor([26.0213, 20.7477, 21.3649])
# Episode 40 terminated after 24 steps
# tensor([17.5587, 17.6790, 17.4710]) tensor([14.0011, 16.8877,  4.6734])
# Episode 41 terminated after 12 steps
# tensor([18.0592, 17.7719, 17.9946]) tensor([17.6521, 13.8504, 20.0152])
# Episode 42 terminated after 30 steps
# tensor([17.9895, 18.8798, 16.9268]) tensor([ 2.2874, 25.2145, 17.0854])
# Episode 45 terminated after 6 steps
# tensor([18.7407, 17.9416, 16.3984]) tensor([21.4249, 18.5547, 16.6681])
# Episode 46 terminated after 45 steps
# tensor([16.6591, 17.3520, 16.6991]) tensor([22.9858,  4.1331, 22.0860])
# Episode 47 terminated after 6 steps
# tensor([16.2888, 17.1416, 15.6390]) tensor([10.4748, 15.6312, 20.9784])
# Episode 48 terminated after 1 steps
# tensor([14.9395, 14.9672, 16.5687]) tensor([ 8.9102, 10.6387, 15.5125])
# Episode 49 terminated after 6 steps
# tensor([14.7187, 14.2404, 14.5885]) tensor([ 9.8727,  6.1384, 21.5850])
# Episode 50 terminated after 6 steps
# tensor([14.9034, 13.6606, 14.6119]) tensor([15.2133, 14.2592, 15.0465])
# Episode 51 terminated after 30 steps
# tensor([13.7889, 13.1086, 13.0857]) tensor([11.5872, 14.1750,  5.1132])
# Episode 52 terminated after 90 steps
# tensor([13.0017, 13.0398, 13.5400]) tensor([20.1702, 13.2104, 18.3309])
# Episode 53 terminated after 35 steps
# tensor([12.6597, 12.4612, 12.6420]) tensor([14.9436, 13.0767,  7.8846])
# Episode 54 terminated after 73 steps
# tensor([12.6120, 12.2763, 12.3807]) tensor([12.1184, 12.1179, 12.6898])
# Episode 55 terminated after 58 steps
# tensor([11.8553, 11.8563, 11.8035]) tensor([10.0984, 22.1595,  9.6791])
# Episode 58 terminated after 4 steps
# tensor([11.8466, 12.0319, 12.0948]) tensor([ 8.3796, 19.5291, 13.4562])
# Episode 59 terminated after 93 steps
# tensor([11.4565, 11.4826, 11.6215]) tensor([11.2231,  1.2634, -6.3485])
# Episode 60 terminated after 6 steps
# tensor([11.5438, 11.9355, 11.6439]) tensor([12.1619, 12.8428,  9.2953])
# Episode 61 terminated after 4 steps
# tensor([11.7335, 11.2085, 11.5647]) tensor([ 8.6769, 13.8790,  7.3609])
# Episode 62 terminated after 23 steps
# tensor([11.4760, 11.3715, 11.3890]) tensor([17.0856, 21.7075,  3.1792])
# Episode 63 terminated after 11 steps
# tensor([11.4173, 11.4862, 11.4665]) tensor([33.9465, 17.7919,  7.3926])
# Episode 64 terminated after 0 steps
# tensor([11.2854, 11.5570, 11.2742]) tensor([11.4224, 12.8119,  8.5733])
# Episode 65 terminated after 57 steps
# tensor([11.6944, 11.7316, 11.4642]) tensor([13.2610, 29.4694, 31.4124])
# Episode 66 terminated after 3 steps
# tensor([11.6740, 11.6492, 11.8112]) tensor([36.5437,  5.6174, 19.8718])
# Episode 67 terminated after 5 steps
# tensor([11.2542, 11.5663, 11.8653]) tensor([ 9.4333, 16.5980,  8.3657])
# Episode 68 terminated after 13 steps
# tensor([11.6401, 11.6000, 12.0223]) tensor([ 18.1985, -12.3612,  21.6644])
# Episode 69 terminated after 1 steps
# tensor([11.6956, 11.7490, 11.8647]) tensor([11.0137, 10.5040, 12.7610])
# Episode 70 terminated after 44 steps
# tensor([11.9702, 11.5347, 12.2353]) tensor([ 9.8144,  8.5327, 11.4692])
# Episode 71 terminated after 35 steps
# tensor([12.1472, 12.5250, 12.6096]) tensor([13.1289, 14.9237,  7.8214])
# Episode 72 terminated after 39 steps
# tensor([12.6133, 12.4587, 12.8951]) tensor([14.1332, 16.7255, 15.8940])
# Episode 73 terminated after 64 steps
# tensor([12.8296, 12.5490, 13.4239]) tensor([16.6483, -5.2796, 26.8529])
# Episode 74 terminated after 16 steps
# tensor([13.0231, 12.6948, 13.5559]) tensor([14.5418, 13.3325, 17.3158])
# Episode 75 terminated after 57 steps
# tensor([13.3659, 13.4921, 12.8770]) tensor([8.0793, 2.0983, 9.1249])
# Episode 76 terminated after 13 steps
# tensor([12.9805, 13.8594, 13.0355]) tensor([1.4222, 9.9562, 7.3299])
# Episode 77 terminated after 1 steps
# tensor([13.1360, 13.1121, 13.0125]) tensor([18.5257,  8.9792, 12.2705])
# Episode 78 terminated after 40 steps
# tensor([14.0157, 13.3477, 12.4519]) tensor([13.8629, 14.9303, 13.9834])
# Episode 79 terminated after 66 steps
# tensor([13.4029, 13.4556, 13.0098]) tensor([17.2579, 14.1798,  9.3507])
# Episode 80 terminated after 0 steps
# tensor([13.4749, 14.4811, 13.4849]) tensor([27.6975, 27.5021, 17.9104])
# Episode 81 terminated after 9 steps
# tensor([13.8938, 13.4192, 13.7525]) tensor([15.4129, 22.9716,  5.7524])
# Episode 82 terminated after 27 steps
# tensor([13.6408, 14.3513, 13.5466]) tensor([-4.9597, 12.7654, 10.2540])
# Episode 83 terminated after 17 steps
# tensor([13.6267, 13.6333, 13.7815]) tensor([20.3690, 14.4047, 12.5804])
# Episode 84 terminated after 62 steps
# tensor([13.8580, 13.7178, 15.2714]) tensor([ 6.6244, 14.7012, 20.7603])
# Episode 85 terminated after 1 steps
# tensor([13.9435, 14.7641, 14.3635]) tensor([ 1.9532, -5.6049, -2.5508])
# tensor([13.9435, 14.6799, 14.9856]) tensor([ 7.3426, 12.0411,  1.2002])
# Episode 86 terminated after 23 steps
# tensor([15.1924, 14.8858, 14.2866]) tensor([24.1903, 20.7168, 17.2164])
# Episode 87 terminated after 7 steps
# tensor([15.0757, 15.2056, 15.4394]) tensor([ 8.4405, 10.5547, 12.7436])
# Episode 88 terminated after 38 steps
# tensor([15.3657, 14.7379, 15.7888]) tensor([19.6027,  9.2122,  9.0149])
# Episode 89 terminated after 51 steps
# tensor([17.1093, 16.5673, 16.1828]) tensor([12.6838, -7.9895,  3.6214])
# Episode 90 terminated after 12 steps
# tensor([16.5326, 16.9571, 16.6809]) tensor([ 7.3922, 38.3929, 19.7238])
# Episode 91 terminated after 3 steps
# tensor([16.6831, 16.9105, 16.1221]) tensor([11.9274,  0.8993, 11.9050])
# Episode 92 terminated after 27 steps
# tensor([17.0352, 16.7194, 17.4192]) tensor([19.0232, 24.3280, 10.1955])
# Episode 93 terminated after 45 steps
# tensor([16.7654, 16.5247, 16.7897]) tensor([8.1493, 6.4782, 3.3028])
# Episode 94 terminated after 6 steps
# tensor([17.1618, 16.6198, 16.8432]) tensor([ 8.3490, 12.8831, 18.7551])
# Episode 95 terminated after 57 steps
# tensor([16.4681, 16.6752, 16.3788]) tensor([35.0570, 15.2343, 18.7636])
# Episode 96 terminated after 12 steps
# tensor([16.1380, 15.0454, 15.7828]) tensor([17.5828,  8.5181, 10.5294])
# Episode 97 terminated after 25 steps
# tensor([16.0761, 16.1268, 16.2999]) tensor([20.7213, 14.8364, 25.3245])
# Episode 98 terminated after 32 steps
# tensor([16.4410, 15.5814, 15.9894]) tensor([18.8156, 18.3551, 11.1216])
# Episode 99 terminated after 17 steps
# tensor([15.5102, 15.8846, 15.3567]) tensor([ 0.3057, 25.2497, 31.0808])
# Episode 100 terminated after 16 steps
# tensor([15.9959, 14.9671, 15.5370]) tensor([ 5.3356, 22.0022, 15.6598])
# Episode 101 terminated after 16 steps
# tensor([15.0269, 15.3011, 15.2913]) tensor([20.4215, -0.6219, 12.3407])
# Episode 102 terminated after 6 steps
# tensor([14.2998, 14.4496, 14.7531]) tensor([11.0981, 12.0721, 11.3072])
# Episode 103 terminated after 16 steps
# tensor([14.3673, 14.0279, 14.4487]) tensor([36.3445, 11.9245, 11.4096])
# Episode 104 terminated after 8 steps
# tensor([14.0591, 13.7757, 14.1893]) tensor([13.8392, 15.3562, 13.4722])
# Episode 105 terminated after 87 steps
# tensor([14.0759, 13.4192, 13.2385]) tensor([21.6989, 24.2079, 19.8356])
# Episode 106 terminated after 18 steps
# tensor([13.3169, 13.0101, 13.1221]) tensor([-5.5542,  5.4678,  3.9941])
# Episode 107 terminated after 6 steps
# tensor([13.1563, 12.5964, 13.1516]) tensor([ 3.6755, 21.8780, 18.8200])
# Episode 108 terminated after 22 steps
# tensor([12.4648, 12.3335, 12.4218]) tensor([17.7108, 16.8169, 16.8704])
# Episode 109 terminated after 26 steps
# tensor([12.2077, 12.3477, 12.6843]) tensor([14.0625, 19.1054,  6.2562])
# Episode 110 terminated after 41 steps
# tensor([12.4173, 12.3324, 12.3199]) tensor([-7.4888, 12.0611, 20.2583])
# Episode 111 terminated after 11 steps
# tensor([12.0975, 11.8395, 12.6797]) tensor([12.3370, 20.4974, -6.4088])
# Episode 112 terminated after 9 steps
# tensor([12.1044, 12.1374, 12.1499]) tensor([16.5147, 19.3666,  7.3035])
# Episode 113 terminated after 17 steps
# tensor([11.9932, 11.9332, 12.2526]) tensor([ 3.9955, -0.4004, 11.7777])
# Episode 114 terminated after 25 steps
# tensor([11.9054, 11.9453, 12.1254]) tensor([11.1355, 13.7345, -0.8407])
# Episode 115 terminated after 15 steps
# tensor([12.0823, 12.3695, 12.0941]) tensor([-2.5354, 21.0573, 20.6270])
# Episode 116 terminated after 1 steps
# tensor([12.1746, 12.2438, 12.1888]) tensor([21.5864, 10.9680, 21.1390])
# Episode 117 terminated after 3 steps
# tensor([12.3634, 11.9629, 12.1422]) tensor([10.0340,  9.9941,  3.5750])
# Episode 118 terminated after 25 steps
# tensor([12.2589, 12.5258, 12.1004]) tensor([17.1349,  9.0736,  5.4354])
# Episode 119 terminated after 15 steps
# tensor([12.1237, 12.4184, 12.6036]) tensor([19.1490, 16.2742, 28.0410])
# Episode 120 terminated after 32 steps
# tensor([12.4882, 12.6236, 12.8113]) tensor([17.6721, 13.0991,  9.7597])
# Episode 121 terminated after 0 steps
# tensor([12.5122, 12.2701, 12.6220]) tensor([ 1.9458, 18.0516,  1.7131])
# Episode 122 terminated after 4 steps
# tensor([12.1359, 12.3433, 12.1819]) tensor([22.9999, 14.5430, -8.5342])
# Episode 123 terminated after 3 steps
# tensor([12.3126, 12.6878, 12.1260]) tensor([ 7.7294, 13.4711,  6.6968])
# Episode 124 terminated after 55 steps
# tensor([12.1311, 12.5517, 12.0666]) tensor([29.6760, 17.1830, 22.7657])
# Episode 125 terminated after 13 steps
# tensor([12.1843, 12.2071, 12.2404]) tensor([30.6078,  0.1673,  6.1536])
# Episode 126 terminated after 11 steps
# tensor([12.2798, 12.2069, 12.4834]) tensor([14.8703,  8.5186,  9.5097])
# Episode 127 terminated after 12 steps
# tensor([12.1612, 12.3591, 12.2698]) tensor([29.2838,  7.9607, 20.6710])
# Episode 128 terminated after 20 steps
# tensor([11.9473, 12.6623, 12.1826]) tensor([ 6.0333, 21.7403,  8.7642])
# Episode 129 terminated after 1 steps
# tensor([12.3545, 12.2362, 12.1301]) tensor([22.8619,  2.2289,  8.9544])
# Episode 130 terminated after 11 steps
# tensor([12.4258, 12.4021, 12.4670]) tensor([18.9962,  5.8301, 18.1951])
# Episode 131 terminated after 9 steps
# tensor([12.6472, 12.4874, 12.9223]) tensor([ 2.6893, 12.2599, 13.4398])
# Episode 132 terminated after 31 steps
# tensor([12.5091, 12.9252, 12.5081]) tensor([19.7735,  8.9618,  3.9882])
# Episode 133 terminated after 14 steps
# tensor([12.7555, 12.7118, 12.6986]) tensor([22.7830, 15.9744,  8.2175])
# Episode 134 terminated after 36 steps
# tensor([12.1011, 12.1802, 12.4216]) tensor([10.1966,  2.5345,  4.1908])
# Episode 135 terminated after 34 steps
# tensor([12.4802, 12.1308, 12.1410]) tensor([ 9.3615, 17.1219, 13.0887])
# Episode 136 terminated after 0 steps
# tensor([12.1077, 11.8996, 12.1862]) tensor([8.4589, 9.3479, 8.7710])
# Episode 137 terminated after 23 steps
# tensor([12.1766, 11.9444, 11.7924]) tensor([10.5853, 12.7880, 26.1663])
# Episode 138 terminated after 30 steps
# tensor([11.6934, 11.6093, 11.9243]) tensor([14.3839, -3.9055,  6.3998])
# Episode 139 terminated after 17 steps
# tensor([11.8388, 11.7989, 11.8587]) tensor([19.2640, 15.4767,  9.4685])
# Episode 140 terminated after 1 steps
# tensor([11.5960, 11.5890, 11.6873]) tensor([14.2283, -5.6114, 13.4625])
# Episode 141 terminated after 2 steps
# tensor([11.6580, 11.6480, 11.5656]) tensor([15.9331, 22.6261,  4.8809])
# Episode 142 terminated after 12 steps
# tensor([11.3079, 11.4701, 11.4725]) tensor([ 3.5259, 23.5971, 14.2979])
# Episode 143 terminated after 2 steps
# tensor([11.3387, 11.2684, 11.3952]) tensor([ 8.0467, 20.1039, 10.1594])
# Episode 144 terminated after 5 steps
# tensor([11.2703, 11.2638, 11.3308]) tensor([16.6923, -3.9951, -8.2811])
# Episode 145 terminated after 29 steps
# tensor([11.3000, 11.3702, 11.1779]) tensor([13.1857,  9.7039, 21.6248])
# Episode 146 terminated after 10 steps
# tensor([11.2125, 11.0719, 11.1310]) tensor([13.1228,  9.4230,  3.9509])
# Episode 147 terminated after 12 steps
# tensor([11.1339, 11.0786, 11.1460]) tensor([ 5.7024, 23.2924,  7.8047])
# Episode 148 terminated after 13 steps
# tensor([11.1350, 11.1076, 11.0861]) tensor([29.3727, 17.4080, 16.0862])
# Episode 149 terminated after 1 steps
# tensor([11.1177, 11.0725, 11.1842]) tensor([ 26.4128,  12.9930, -13.8406])
# Episode 150 terminated after 5 steps
# tensor([11.1899, 11.1652, 11.2329]) tensor([24.8366, 30.8148,  6.8305])
# Episode 151 terminated after 26 steps
# tensor([11.1485, 11.1433, 11.2339]) tensor([-5.6874,  6.3225, 19.5900])
# Episode 152 terminated after 3 steps
# tensor([11.2129, 11.2278, 11.0913]) tensor([17.8430, 16.0476, 22.8618])
# Episode 153 terminated after 5 steps
# tensor([11.2463, 11.4196, 11.3405]) tensor([14.8373,  1.1744, 17.4641])
# Episode 154 terminated after 10 steps
# tensor([11.3809, 11.3377, 11.3359]) tensor([ 3.3055,  6.3740, 19.7856])
# Episode 155 terminated after 0 steps
# tensor([11.4935, 11.5326, 11.4504]) tensor([25.3107, 12.4668, -6.0486])
# Episode 156 terminated after 5 steps
# tensor([11.5955, 11.3756, 11.5576]) tensor([ 9.2722, -0.0549, 21.0638])
# Episode 157 terminated after 2 steps
# tensor([11.5034, 11.6596, 11.4093]) tensor([34.0490,  7.8444, 15.0621])
# Episode 158 terminated after 6 steps
# tensor([11.5321, 11.5301, 11.3832]) tensor([-12.9601,  24.2031,  -3.0463])
# Episode 159 terminated after 5 steps
# tensor([11.5299, 11.5002, 11.4105]) tensor([ 2.7189,  0.6407, 16.3974])
# Episode 160 terminated after 7 steps
# tensor([11.5383, 11.2031, 11.6613]) tensor([ 7.3453, 17.4881, 14.1348])
# Episode 161 terminated after 21 steps
# tensor([11.5045, 11.6092, 11.6096]) tensor([18.0592, 15.5268, 27.6153])
# Episode 162 terminated after 13 steps
# tensor([11.6609, 11.5429, 11.6365]) tensor([20.5135, 33.7440, 20.6431])
# Episode 163 terminated after 0 steps
# tensor([11.5722, 11.7427, 11.5587]) tensor([10.6423,  4.4558, 12.1841])
# Episode 164 terminated after 3 steps
# tensor([11.6751, 11.5921, 11.5508]) tensor([ 8.5487, 22.5375, 19.0821])
# Episode 165 terminated after 15 steps
# tensor([11.6513, 11.5273, 11.6328]) tensor([24.8426,  4.3560,  6.8671])
# Episode 166 terminated after 3 steps
# tensor([11.6310, 11.4886, 11.4612]) tensor([14.7192, 12.1034,  5.0501])
# Episode 167 terminated after 16 steps
# tensor([11.4097, 11.3012, 11.3455]) tensor([-11.5285,  10.7595,   9.9367])
# Episode 168 terminated after 14 steps
# tensor([11.4102, 11.3709, 11.3418]) tensor([ 8.0148, 22.9570, 20.1334])
# Episode 169 terminated after 0 steps
# tensor([11.5867, 11.5938, 11.6605]) tensor([17.8691,  3.7404, 14.1117])
# Episode 170 terminated after 25 steps
# tensor([11.6299, 11.4853, 11.7329]) tensor([25.9908, 19.5669, 28.8299])
# Episode 171 terminated after 25 steps
# tensor([12.0342, 11.5941, 11.6590]) tensor([23.2809, 20.6568, 26.0185])
# Episode 172 terminated after 40 steps
# tensor([12.0337, 11.7824, 11.8357]) tensor([18.0109, 20.9330, 11.3045])
# Episode 173 terminated after 8 steps
# tensor([12.1786, 12.1173, 12.0127]) tensor([ 0.9095, 14.3787,  7.0849])
# Episode 174 terminated after 2 steps
# tensor([12.2999, 12.1700, 11.8537]) tensor([24.3848, 10.8264,  2.9009])
# Episode 175 terminated after 4 steps
# tensor([11.9691, 12.1062, 11.5975]) tensor([-1.9852, -4.8267,  7.7562])
# Episode 176 terminated after 0 steps
# tensor([12.0342, 12.2527, 11.9704]) tensor([31.1844,  2.1019,  9.8626])
# Episode 177 terminated after 6 steps
# tensor([12.2638, 12.2067, 12.2487]) tensor([13.8936, 33.6816, 24.4955])
# Episode 178 terminated after 10 steps
# tensor([12.1640, 12.1021, 12.1855]) tensor([21.2891,  7.0433, 14.0651])
# Episode 179 terminated after 4 steps
# tensor([12.1840, 12.2274, 12.4028]) tensor([1.8295, 8.1429, 9.1633])
# Episode 180 terminated after 64 steps
# tensor([12.8231, 12.3703, 12.6580]) tensor([29.5031,  6.5978, 23.2172])
# Episode 181 terminated after 15 steps
# tensor([12.5467, 12.5560, 12.4775]) tensor([ 6.3188, 20.5445, 14.1742])
# Episode 182 terminated after 7 steps
# tensor([12.6222, 12.8878, 12.2981]) tensor([-3.1646, 16.0167, 14.2681])
# Episode 183 terminated after 15 steps
# tensor([13.0023, 12.7412, 13.1150]) tensor([2.5764, 7.6309, 8.0305])
# Episode 184 terminated after 5 steps
# tensor([12.8035, 13.2392, 13.0826]) tensor([ 1.2441, 15.3143, 12.7039])
# Episode 185 terminated after 6 steps
# tensor([13.2710, 13.4535, 12.3734]) tensor([ 9.1054,  5.9303, 22.0774])
# Episode 186 terminated after 1 steps
# tensor([13.4334, 13.1979, 12.8349]) tensor([ 9.2444, 21.8030,  8.2593])
# Episode 187 terminated after 15 steps
# tensor([13.2251, 12.9980, 13.5239]) tensor([ 9.3728, 14.0174, 12.5137])
# Episode 188 terminated after 13 steps
# tensor([12.6168, 14.1555, 13.6470]) tensor([17.5736,  5.7565, 18.9648])
# Episode 189 terminated after 3 steps
# tensor([14.6918, 13.7969, 13.7001]) tensor([13.2830, 22.7966, 16.9236])
# Episode 190 terminated after 0 steps
# tensor([15.5266, 14.2764, 14.6696]) tensor([ 2.2862, 26.9036, 23.1471])
# Episode 191 terminated after 5 steps
# tensor([15.3582, 15.1599, 15.5236]) tensor([ 6.2143, 10.7871, 16.3292])
# Episode 192 terminated after 6 steps
# tensor([15.2436, 15.6526, 16.1740]) tensor([18.9713, -7.7579, 18.2031])
# Episode 193 terminated after 0 steps
# tensor([16.0334, 16.3991, 15.3197]) tensor([13.7962, 10.3331, 12.8522])
# Episode 194 terminated after 6 steps
# tensor([15.8890, 16.2466, 15.3712]) tensor([12.0169,  7.7018, 15.4500])
# Episode 195 terminated after 15 steps
# tensor([17.4242, 15.9427, 16.4411]) tensor([28.2913,  8.1030, 10.8153])
# Episode 196 terminated after 2 steps
# tensor([16.0220, 16.3602, 15.3579]) tensor([10.7109, 31.4559, 30.9040])
# Episode 197 terminated after 3 steps
# tensor([16.1566, 16.0771, 17.4164]) tensor([16.2956, 15.6518, 26.7088])
# Episode 198 terminated after 0 steps
# tensor([18.1166, 18.4499, 17.7411]) tensor([15.4529,  6.9352, 19.5143])
# Episode 199 terminated after 3 steps
# tensor([17.7630, 18.9017, 17.6555]) tensor([22.2703, 18.5365, 26.0180])
# Episode 200 terminated after 0 steps
# tensor([18.3677, 19.0834, 18.5713]) tensor([ 8.7985, 24.6244, 12.9044])
# Episode 201 terminated after 8 steps
# tensor([19.9045, 18.8689, 18.5737]) tensor([14.5497, 24.4050, 29.9680])
# Episode 202 terminated after 3 steps
# tensor([20.1553, 19.7828, 19.8921]) tensor([24.9848, 21.0999, 18.7788])
# Episode 203 terminated after 6 steps
# tensor([18.3745, 19.9016, 20.3103]) tensor([ 5.5833, 14.8086, 20.1391])
# Episode 204 terminated after 11 steps
# tensor([19.5919, 20.9518, 20.7138]) tensor([-4.8542, 26.5423, 37.7336])
# Episode 205 terminated after 20 steps
# tensor([20.6368, 19.8154, 20.2892]) tensor([22.2441, 16.7704, 17.6089])
# Episode 206 terminated after 31 steps
# tensor([20.0127, 19.9770, 19.7133]) tensor([ 0.7123, 37.9792, -1.4934])
# Episode 207 terminated after 3 steps
# tensor([19.8322, 19.2581, 19.7692]) tensor([12.3983, -5.9252, 29.3162])
# Episode 208 terminated after 8 steps
# tensor([18.3233, 17.7911, 18.8318]) tensor([11.9530, 16.3355,  2.1995])
# Episode 209 terminated after 1 steps
# tensor([18.3871, 18.7999, 16.0679]) tensor([25.9450, 29.4718, 10.4223])
# Episode 210 terminated after 12 steps
# tensor([18.1484, 18.1087, 18.1928]) tensor([5.1074, 7.0650, 1.5859])
# Episode 211 terminated after 4 steps
# tensor([17.7274, 18.7450, 18.1605]) tensor([23.8551,  3.7759, 15.8952])
# Episode 212 terminated after 4 steps
# tensor([17.5578, 17.7829, 16.2746]) tensor([33.7701, -3.8641, -3.6137])
# Episode 213 terminated after 11 steps
# tensor([16.8122, 17.0486, 16.4127]) tensor([ 5.2810, 25.1389, 30.0769])
# Episode 214 terminated after 10 steps
# tensor([15.7686, 16.2628, 16.7978]) tensor([32.8322, 22.6865, 10.6294])
# Episode 215 terminated after 16 steps
# tensor([16.2250, 15.0198, 16.3219]) tensor([26.6522, 17.6277, 18.4096])
# Episode 216 terminated after 3 steps
# tensor([15.6830, 15.6648, 15.3279]) tensor([-12.1791,   7.7188,  13.6512])
# Episode 217 terminated after 0 steps
# tensor([15.3196, 15.8684, 15.1959]) tensor([ 0.6437,  1.1943, 20.2130])
# Episode 218 terminated after 1 steps
# tensor([14.7160, 14.9028, 14.7180]) tensor([18.9488, 15.3707, 10.1901])
# Episode 219 terminated after 6 steps
# tensor([14.6703, 15.3426, 14.6110]) tensor([22.1635,  9.4131, 14.7689])
# Episode 220 terminated after 6 steps
# tensor([14.1805, 14.3439, 14.1509]) tensor([12.9983, 26.0813, -3.8792])
# Episode 221 terminated after 4 steps
# tensor([13.6823, 13.9174, 13.7569]) tensor([19.2331, -3.0572, 13.0779])
# Episode 222 terminated after 17 steps
# tensor([13.4293, 13.3082, 13.3469]) tensor([5.0872, 7.4372, 9.4327])
# Episode 223 terminated after 6 steps
# tensor([13.3008, 13.1489, 12.8784]) tensor([13.0974, 18.5745,  4.4136])
# Episode 224 terminated after 36 steps
# tensor([12.7681, 12.6540, 12.8132]) tensor([29.8023, 14.7357, 23.2529])
# Episode 225 terminated after 1 steps
# tensor([12.3423, 12.5046, 12.2024]) tensor([-0.0816,  8.3967, -0.1236])
# Episode 226 terminated after 18 steps
# tensor([12.0988, 12.2439, 12.1851]) tensor([ 6.4837,  1.1209, 13.1150])
# Episode 227 terminated after 10 steps
# tensor([12.1251, 12.0782, 12.1608]) tensor([14.0809, 33.8284, 13.2140])
# Episode 228 terminated after 21 steps
# tensor([12.1222, 12.1017, 12.0994]) tensor([14.7870, 12.3428, 28.9320])
# Episode 229 terminated after 5 steps
# tensor([12.2197, 12.0266, 12.1974]) tensor([11.4629, 26.7329,  6.4091])
# Episode 230 terminated after 0 steps
# tensor([12.5280, 12.4183, 12.2495]) tensor([ 9.3924, 20.3461,  7.1018])
# Episode 231 terminated after 1 steps
# tensor([12.2618, 12.0214, 12.2066]) tensor([14.0442, 20.9675,  2.2040])
# Episode 232 terminated after 4 steps
# tensor([12.5159, 12.2817, 12.5997]) tensor([18.3268,  9.3869, 24.0442])
# Episode 233 terminated after 5 steps
# tensor([12.4073, 12.3823, 12.6842]) tensor([30.9013,  5.0122,  1.9429])
# Episode 234 terminated after 13 steps
# tensor([12.4796, 12.3174, 12.4954]) tensor([21.8303, 21.1613, 11.7596])
# Episode 235 terminated after 11 steps
# tensor([12.4437, 12.5586, 12.5526]) tensor([ 5.2383, -1.8732, 27.1220])
# Episode 236 terminated after 17 steps
# tensor([12.6412, 12.8002, 12.6496]) tensor([23.6953,  8.7376, 15.6110])
# Episode 237 terminated after 15 steps
# tensor([12.8035, 12.8098, 12.8816]) tensor([4.5486, 2.5073, 0.2170])
# Episode 238 terminated after 9 steps
# tensor([12.8968, 12.5989, 12.7674]) tensor([ 4.7623,  5.0539, 21.4218])
# Episode 239 terminated after 8 steps
# tensor([12.9914, 13.0194, 13.0364]) tensor([20.7888, 33.0569,  1.8931])
# Episode 240 terminated after 2 steps
# tensor([13.0084, 13.0469, 13.0537]) tensor([14.2793, 24.9752,  5.6774])
# Episode 241 terminated after 21 steps
# tensor([13.0098, 12.8840, 12.8412]) tensor([17.4114, 16.7688, 17.0284])
# Episode 242 terminated after 3 steps
# tensor([12.9333, 13.4645, 13.0817]) tensor([19.2319,  4.4072, 26.2586])
# Episode 243 terminated after 7 steps
# tensor([12.9206, 12.8407, 12.9426]) tensor([19.1362, 20.4874,  4.6954])
# Episode 244 terminated after 0 steps
# tensor([13.2451, 13.2048, 13.2472]) tensor([ 7.0903, 18.0936, 26.6854])
# Episode 245 terminated after 22 steps
# tensor([13.2698, 13.0933, 13.2293]) tensor([15.5727,  2.0128,  0.8134])
# Episode 246 terminated after 2 steps
# tensor([13.4155, 13.4418, 13.1808]) tensor([19.1852,  7.3901,  1.6722])
# Episode 247 terminated after 4 steps
# tensor([13.0607, 13.4927, 13.4335]) tensor([19.4922, 16.0401, 17.2649])
# Episode 248 terminated after 16 steps
# tensor([13.7384, 13.8015, 14.4367]) tensor([11.7893,  6.5840, 17.2968])
# Episode 249 terminated after 3 steps
# tensor([13.7050, 13.4321, 13.4230]) tensor([18.6117, 27.4440,  3.0836])
# Episode 250 terminated after 2 steps
# tensor([13.8898, 13.7365, 13.5808]) tensor([17.1387,  0.7953,  5.5664])
# Episode 251 terminated after 19 steps
# tensor([13.6611, 14.1553, 13.8453]) tensor([15.8219, -1.7792, 13.8372])
# Episode 252 terminated after 10 steps
# tensor([13.7967, 13.7229, 13.4567]) tensor([17.4853, 18.3014, 11.7359])
# Episode 253 terminated after 20 steps
# tensor([13.9229, 13.3439, 13.8693]) tensor([-2.2072, 23.6062, 26.1685])
# Episode 254 terminated after 6 steps
# tensor([13.5823, 13.3975, 14.1595]) tensor([ 6.7070, 21.6662, 25.4205])
# Episode 255 terminated after 0 steps
# tensor([13.6552, 13.7204, 13.9864]) tensor([ 1.2650, -2.3052, 20.4525])
# Episode 256 terminated after 2 steps
# tensor([13.9266, 13.8784, 13.9263]) tensor([ 5.7796, 31.5124, 13.3193])
# Episode 257 terminated after 13 steps
# tensor([14.5972, 13.1959, 14.2925]) tensor([24.7469, 31.1626, 28.3211])
# Episode 258 terminated after 0 steps
# tensor([13.9533, 13.6905, 13.6926]) tensor([22.7241, 33.1109, 22.9978])
# Episode 259 terminated after 4 steps
# tensor([13.4047, 12.9238, 13.6092]) tensor([17.8950, 15.5871, 20.5469])
# Episode 260 terminated after 0 steps
# tensor([13.6347, 13.5586, 13.6706]) tensor([ 7.5684, 20.0424, 16.7840])
# Episode 261 terminated after 14 steps
# tensor([13.3958, 13.7089, 13.4535]) tensor([10.7857,  7.7833,  4.7137])
# Episode 262 terminated after 6 steps
# tensor([13.4466, 13.2614, 13.0729]) tensor([1.5306e-03, 2.0254e+01, 1.1100e+01])
# Episode 263 terminated after 3 steps
# tensor([13.0366, 12.9293, 13.1418]) tensor([ 8.5356,  3.4317, 17.4604])
# Episode 264 terminated after 3 steps
# tensor([12.6277, 12.8148, 12.7947]) tensor([15.5405, 14.1703, 24.5414])
# Episode 265 terminated after 7 steps
# tensor([12.4735, 12.5059, 12.6436]) tensor([15.9007, -2.3989,  9.1240])
# Episode 266 terminated after 2 steps
# tensor([12.1652, 12.1101, 12.0458]) tensor([10.4995, 11.5709, -2.9549])
# Episode 267 terminated after 5 steps
# tensor([12.2187, 11.9345, 11.7899]) tensor([13.4312, 10.9958, -5.0166])
# Episode 268 terminated after 4 steps
# tensor([11.7453, 11.4094, 11.3950]) tensor([ 2.3621,  3.0531, 22.2599])
# Episode 269 terminated after 0 steps
# tensor([11.2260, 11.2901, 11.3928]) tensor([16.4233, 14.6453,  5.3439])
# Episode 270 terminated after 13 steps
# tensor([11.1536, 11.1438, 11.1286]) tensor([-21.5620,   9.0351,  11.2789])
# Episode 271 terminated after 4 steps
# tensor([10.9171, 10.9530, 10.7573]) tensor([23.8522,  3.0683, 14.1766])
# Episode 272 terminated after 2 steps
# tensor([10.8797, 10.7702, 10.8639]) tensor([17.7331, 24.9844, 33.1446])
# Episode 273 terminated after 7 steps
# tensor([10.7666, 10.7551, 10.8112]) tensor([14.2356, 13.7961, 25.2694])
# Episode 274 terminated after 5 steps
# tensor([10.7223, 10.7515, 10.7101]) tensor([ 8.9754, -0.0714, -3.3522])
# Episode 275 terminated after 4 steps
# tensor([10.6637, 10.7106, 10.6913]) tensor([13.9491,  9.0019, 13.8589])
# Episode 276 terminated after 1 steps
# tensor([10.6117, 10.6275, 10.5959]) tensor([-5.0536,  8.2075, 12.0870])
# Episode 277 terminated after 10 steps
# tensor([10.6329, 10.6113, 10.6160]) tensor([15.0899, 16.9299, 10.6067])
# Episode 278 terminated after 7 steps
# tensor([10.5965, 10.5870, 10.6183]) tensor([29.8765, 19.7365,  0.3718])
# Episode 279 terminated after 12 steps
# tensor([10.6120, 10.6081, 10.6320]) tensor([21.9035,  1.2756, -1.9153])
# Episode 280 terminated after 10 steps
# tensor([10.7041, 10.6290, 10.6376]) tensor([ 3.9826, 12.1939,  5.1702])
# Episode 281 terminated after 6 steps
# tensor([10.6780, 10.6723, 10.6663]) tensor([ 8.9726,  9.7940, 17.5550])
# Episode 282 terminated after 5 steps
# tensor([10.7288, 10.6873, 10.7991]) tensor([12.6965, 18.5011, -0.9215])
# Episode 283 terminated after 0 steps
# tensor([10.7987, 10.7277, 10.6601]) tensor([12.9404, 18.2026, -5.1021])
# Episode 284 terminated after 4 steps
# tensor([10.7965, 10.8447, 10.8561]) tensor([10.9913, 11.3779,  6.8598])
# Episode 285 terminated after 4 steps
# tensor([10.8453, 10.8341, 10.8231]) tensor([17.9786, 19.1049, 22.7725])
# Episode 286 terminated after 16 steps
# tensor([10.8949, 10.8228, 10.9224]) tensor([ 16.4439,  18.5120, -13.1995])
# Episode 287 terminated after 13 steps
# tensor([10.9121, 10.9946, 11.0152]) tensor([16.6039, -0.7751, 21.7243])
# Episode 288 terminated after 2 steps
# tensor([11.0860, 11.0644, 11.0130]) tensor([ 1.9402, 18.1849,  3.6197])
# Episode 289 terminated after 3 steps
# tensor([11.3901, 11.1374, 11.2061]) tensor([ 6.2228, 28.1496, 10.1738])
# Episode 290 terminated after 0 steps
# tensor([11.2504, 11.4718, 11.3478]) tensor([14.6545, 17.7951, 13.8117])
# Episode 291 terminated after 16 steps
# tensor([11.6052, 11.5856, 11.5875]) tensor([15.0044, 16.2305, 10.3307])
# Episode 292 terminated after 9 steps
# tensor([11.8293, 11.7874, 11.7995]) tensor([18.9912, 11.3640, -0.3786])
# Episode 293 terminated after 1 steps
# tensor([11.9387, 11.9730, 11.9913]) tensor([ 3.8639, 10.0204,  3.0953])
# Episode 294 terminated after 25 steps
# tensor([12.2044, 12.1888, 12.1449]) tensor([14.7745, 14.2795,  7.8020])
# Episode 295 terminated after 6 steps
# tensor([12.3109, 12.5604, 12.3103]) tensor([ 9.1643, 11.7413,  2.1530])
# Episode 296 terminated after 2 steps
# tensor([12.5770, 12.6530, 12.3698]) tensor([13.1887,  8.2744,  8.1651])
# Episode 297 terminated after 0 steps
# tensor([12.7102, 12.7086, 12.8411]) tensor([15.8725,  6.9136,  8.6487])
# Episode 298 terminated after 1 steps
# tensor([12.8193, 12.3041, 12.5808]) tensor([ 4.2479, 23.5985,  9.6610])
# Episode 299 terminated after 1 steps
# tensor([12.7751, 12.6258, 12.6762]) tensor([6.0932, 4.7685, 8.9611])
# Episode 300 terminated after 12 steps
# tensor([12.3423, 12.3288, 12.5793]) tensor([25.4161, 16.0228, -6.2341])
# Episode 301 terminated after 10 steps
# tensor([12.4868, 12.5636, 12.3228]) tensor([14.9245,  5.3054, 21.3863])
# Episode 302 terminated after 6 steps
# tensor([12.3446, 12.3699, 12.3426]) tensor([ 4.0401, 29.5265,  4.2758])
# Episode 303 terminated after 23 steps
# tensor([12.1693, 12.3003, 12.5330]) tensor([-14.9193,  14.7880,  11.6573])
# Episode 304 terminated after 2 steps
# tensor([12.6000, 12.4617, 12.5688]) tensor([-0.1658, 20.7519,  4.1517])
# Episode 305 terminated after 4 steps
# tensor([13.0149, 12.9424, 12.6717]) tensor([25.5914,  8.6548, 20.2188])
# Episode 306 terminated after 13 steps
# tensor([12.9777, 13.0347, 13.2206]) tensor([ 5.1081, 16.8068, 29.2051])
# Episode 307 terminated after 3 steps
# tensor([13.3793, 13.1647, 13.4949]) tensor([ 6.7495, 26.7853, 21.9344])
# Episode 308 terminated after 3 steps
# tensor([13.4145, 13.7309, 13.6274]) tensor([-1.0001, 21.1295,  3.4812])
# Episode 309 terminated after 2 steps
# tensor([13.8002, 13.5149, 13.8501]) tensor([22.1180,  4.1315, 14.1869])
# Episode 310 terminated after 3 steps
# tensor([14.7546, 14.4552, 14.5455]) tensor([13.3130, 11.9131,  6.1965])
# Episode 311 terminated after 1 steps
# tensor([14.4599, 15.0220, 14.7917]) tensor([17.7455, 34.5665, 12.8438])
# Episode 312 terminated after 2 steps
# tensor([15.0906, 14.9371, 15.1729]) tensor([10.8368,  8.0567,  7.6912])
# Episode 313 terminated after 9 steps
# tensor([15.2039, 15.1518, 14.8971]) tensor([17.3199, 17.6265, 21.8646])
# Episode 314 terminated after 6 steps
# tensor([14.3145, 14.9551, 14.9916]) tensor([22.8001, 36.7096, 14.3984])
# Episode 315 terminated after 0 steps
# tensor([14.6027, 14.5911, 14.8530]) tensor([24.5136, 26.4960, 13.5569])
# Episode 316 terminated after 1 steps
# tensor([14.7763, 14.9149, 15.5340]) tensor([ 1.7886, 19.4954, -3.7493])
# Episode 317 terminated after 2 steps
# tensor([14.8268, 15.0511, 15.1566]) tensor([ 9.9355, 37.1560, 14.4137])
# Episode 318 terminated after 6 steps
# tensor([15.0252, 15.2969, 15.2964]) tensor([10.3143, 18.7551,  6.3752])
# Episode 319 terminated after 6 steps
# tensor([15.3041, 15.5672, 15.2959]) tensor([16.8134, 26.0775, 15.8089])
# Episode 320 terminated after 0 steps
# tensor([15.5494, 15.3408, 15.0079]) tensor([15.0382, 15.4343, 15.6856])
# Episode 321 terminated after 1 steps
# tensor([15.6966, 15.7150, 15.5574]) tensor([ 6.5920,  2.5317, 12.1371])
# Episode 322 terminated after 7 steps
# tensor([15.3784, 15.5879, 14.7834]) tensor([-5.3920,  9.1669, 16.2255])
# Episode 323 terminated after 20 steps
# tensor([15.2922, 14.8846, 14.5248]) tensor([ 8.8839, 18.3664,  8.0328])
# Episode 324 terminated after 0 steps
# tensor([14.9221, 15.2752, 14.7830]) tensor([27.4518, 27.3209, 17.6501])
# Episode 325 terminated after 3 steps
# tensor([13.7229, 14.7668, 13.8756]) tensor([28.8398, 15.0333, 26.7639])
# Episode 326 terminated after 0 steps
# tensor([13.7311, 14.2462, 13.7258]) tensor([20.7575, 13.0069, 13.1773])
# Episode 327 terminated after 6 steps
# tensor([13.8934, 13.6013, 13.6758]) tensor([29.2596,  2.8201, 19.1437])
# Episode 328 terminated after 2 steps
# tensor([13.1646, 12.7944, 13.0925]) tensor([14.0812, 18.9467, -9.0740])
# Episode 329 terminated after 0 steps
# tensor([12.9040, 12.8410, 12.8317]) tensor([26.9581, -2.1408, 24.3546])
# Episode 330 terminated after 4 steps
# tensor([12.8454, 12.8625, 12.8162]) tensor([ 9.0071,  4.2092, 17.9011])
# Episode 331 terminated after 0 steps
# tensor([12.5734, 12.1907, 12.5118]) tensor([4.4983, 1.9618, 2.9405])
# tensor([12.5701, 12.1931, 12.3095]) tensor([26.1347,  6.7658,  6.8229])
# Episode 332 terminated after 10 steps
# tensor([12.3122, 12.1461, 12.0372]) tensor([20.8914,  5.4747, 18.4983])
# Episode 333 terminated after 0 steps
# tensor([11.8348, 12.0221, 11.9222]) tensor([13.7464, 26.1812, 19.9281])
# Episode 334 terminated after 5 steps
# tensor([12.0950, 11.7954, 11.9358]) tensor([14.9521,  4.0831,  9.3168])
# Episode 335 terminated after 2 steps
# tensor([11.6894, 12.0608, 11.5399]) tensor([15.0814, 28.5893,  7.4165])
# Episode 336 terminated after 0 steps
# tensor([11.7495, 11.8196, 11.6722]) tensor([15.3301,  8.5999, 16.1960])
# Episode 337 terminated after 6 steps
# tensor([11.8964, 11.9268, 11.9531]) tensor([14.6933,  2.0003, 14.1864])
# Episode 338 terminated after 4 steps
# tensor([11.7841, 12.1451, 11.9464]) tensor([11.4100,  5.4904, 32.8992])
# Episode 339 terminated after 9 steps
# tensor([11.8608, 12.0752, 12.0918]) tensor([23.9653, 18.9540,  4.3730])
# Episode 340 terminated after 0 steps
# tensor([12.1046, 11.8842, 11.9258]) tensor([13.7082, 12.4042, -0.6471])
# Episode 341 terminated after 5 steps
# tensor([12.0210, 12.0451, 12.0535]) tensor([28.2219, 19.2980, 12.6929])
# Episode 342 terminated after 0 steps
# tensor([12.2735, 12.1336, 12.1999]) tensor([-9.4526, 17.5364,  8.5108])
# Episode 343 terminated after 2 steps
# tensor([12.5138, 12.4077, 12.4059]) tensor([16.5852, 14.4575, -4.8027])
# Episode 344 terminated after 12 steps
# tensor([12.1936, 12.1952, 12.1801]) tensor([ 4.8654,  8.0566, -7.9397])
# Episode 345 terminated after 2 steps
# tensor([12.2456, 12.1592, 12.2544]) tensor([15.9114, 15.1614,  7.0391])
# Episode 346 terminated after 5 steps
# tensor([12.6057, 12.2489, 12.2615]) tensor([18.0155,  9.9661, 13.3497])
# Episode 347 terminated after 2 steps
# tensor([12.5105, 12.3222, 12.4931]) tensor([ 8.0142,  4.4267, 11.3188])
# Episode 348 terminated after 13 steps
# tensor([12.2792, 12.4289, 12.4221]) tensor([ 1.3650,  3.6702, 14.1691])
# Episode 349 terminated after 6 steps
# tensor([12.6770, 12.4756, 12.6186]) tensor([10.8240, 14.5201, 17.2927])
# Episode 350 terminated after 6 steps
# tensor([12.7337, 12.9846, 12.6991]) tensor([ 0.3060, -3.9774, 14.2102])
# Episode 351 terminated after 10 steps
# tensor([12.7614, 13.1953, 12.9289]) tensor([-7.6254, 10.2935,  6.9088])
# Episode 352 terminated after 2 steps
# tensor([12.9803, 13.0588, 13.0329]) tensor([19.7784,  7.1048, 17.8548])
# Episode 353 terminated after 3 steps
# tensor([13.2017, 12.8220, 12.9801]) tensor([ 0.0535, 21.8350, 40.7261])
# Episode 354 terminated after 15 steps
# tensor([12.8563, 12.9277, 12.7728]) tensor([ 7.0035, 11.7235, -2.9683])
# Episode 355 terminated after 0 steps
# tensor([12.4208, 12.7678, 12.7178]) tensor([20.6312,  3.9761, 25.6340])
# Episode 356 terminated after 0 steps
# tensor([12.8438, 12.6718, 12.7867]) tensor([ 5.0264, 16.1922, 18.5068])
# Episode 357 terminated after 5 steps
# tensor([12.4905, 12.3327, 12.3674]) tensor([21.8770,  8.5001, 20.7814])
# Episode 358 terminated after 3 steps
# tensor([12.4142, 12.2225, 12.3719]) tensor([23.8056, 10.5415, 19.9340])
# Episode 359 terminated after 2 steps
# tensor([12.3970, 12.1085, 12.2366]) tensor([ 8.8671,  9.7276, 20.0303])
# Episode 360 terminated after 4 steps
# tensor([12.0758, 12.1970, 12.0845]) tensor([32.0890,  8.4276, 22.3978])
# Episode 361 terminated after 12 steps
# tensor([12.1481, 11.9943, 12.0492]) tensor([24.2523,  7.7802, 11.5114])
# Episode 362 terminated after 6 steps
# tensor([12.1502, 12.1944, 11.7935]) tensor([  5.5408,  18.2388, -13.2207])
# Episode 363 terminated after 4 steps
# tensor([12.2829, 12.2107, 12.1107]) tensor([-1.2156, 18.1799, 26.3721])
# Episode 364 terminated after 7 steps
# tensor([12.0111, 12.3644, 12.2053]) tensor([13.6511,  4.0348,  2.8469])
# Episode 365 terminated after 8 steps
# tensor([12.2889, 12.5622, 12.1920]) tensor([11.2747, 10.3357, 17.2999])
# Episode 366 terminated after 5 steps
# tensor([12.3091, 12.4695, 12.2947]) tensor([25.8857, 14.8180, 16.5931])
# Episode 367 terminated after 1 steps
# tensor([12.5211, 12.6882, 12.4599]) tensor([ 0.1289, 22.5872, 25.3173])
# Episode 368 terminated after 5 steps
# tensor([12.4269, 12.4076, 12.5976]) tensor([10.2174, 21.1150,  3.5698])
# Episode 369 terminated after 0 steps
# tensor([12.5265, 12.2990, 12.5175]) tensor([ 4.6978, -9.6854, 14.3732])
# Episode 370 terminated after 0 steps
# tensor([12.5803, 12.4680, 12.5674]) tensor([ 4.8043, 12.1181,  2.8631])
# Episode 371 terminated after 30 steps
# tensor([12.1342, 12.1274, 12.4937]) tensor([14.8420, -5.4432,  1.0121])
# Episode 372 terminated after 4 steps
# tensor([12.3363, 12.2254, 12.4023]) tensor([29.1027, 19.1991,  1.3518])
# Episode 373 terminated after 2 steps
# tensor([11.8251, 11.7318, 12.0265]) tensor([ 6.7072, 11.4354, 15.1266])
# Episode 374 terminated after 2 steps
# tensor([11.6641, 12.1116, 11.6631]) tensor([16.6438,  7.0630, 26.7806])
# Episode 375 terminated after 5 steps
# tensor([11.7668, 11.5509, 11.5399]) tensor([6.5871, 0.8150, 1.2980])
# Episode 376 terminated after 2 steps
# tensor([11.6252, 11.5605, 11.5839]) tensor([21.0778,  2.8358, 13.8785])
# Episode 377 terminated after 3 steps
# tensor([11.2889, 11.6911, 11.3858]) tensor([21.8499, 12.4241, 21.3620])
# Episode 378 terminated after 4 steps
# tensor([11.2237, 11.1597, 11.2365]) tensor([ 4.1418,  8.1786, 13.7618])
# Episode 379 terminated after 2 steps
# tensor([11.1726, 11.1772, 11.3112]) tensor([14.1194, -6.1954, 19.8608])
# Episode 380 terminated after 5 steps
# tensor([10.9563, 11.0333, 11.1224]) tensor([ 1.2708, 12.2718, 22.2490])
# Episode 381 terminated after 6 steps
# tensor([10.9692, 11.0717, 10.9294]) tensor([ 3.7349, 11.3095, 26.1427])
# Episode 382 terminated after 3 steps
# tensor([11.1061, 10.9351, 11.0255]) tensor([12.3102, -6.4031, 15.6963])
# Episode 383 terminated after 3 steps
# tensor([10.9767, 10.8301, 10.8854]) tensor([ 7.0867,  8.9308, 13.8640])
# Episode 384 terminated after 7 steps
# tensor([11.1328, 11.0147, 10.8935]) tensor([-1.8321, 24.6611, -5.4441])
# Episode 385 terminated after 0 steps
# tensor([10.8767, 11.0223, 10.9495]) tensor([ 3.4930,  3.0141, 14.5468])
# Episode 386 terminated after 1 steps
# tensor([10.9652, 10.9225, 10.8458]) tensor([24.1546,  8.1562, 21.4190])
# Episode 387 terminated after 10 steps
# tensor([10.9130, 10.8730, 10.9245]) tensor([-2.6431,  4.0931, 19.7747])
# Episode 388 terminated after 4 steps
# tensor([10.7780, 10.8377, 10.7974]) tensor([20.1975, 23.2532, 24.5754])
# Episode 389 terminated after 4 steps
# tensor([10.7915, 10.8593, 10.8978]) tensor([18.1234, 15.2984, 15.3531])
# Episode 390 terminated after 8 steps
# tensor([10.8377, 10.9411, 10.9501]) tensor([ 5.9964, 24.4822, -0.7864])
# Episode 391 terminated after 12 steps
# tensor([10.9270, 11.0208, 10.8833]) tensor([13.8249, -0.6411, 18.4816])
# Episode 392 terminated after 0 steps
# tensor([10.9805, 10.8264, 10.9711]) tensor([23.7763,  7.2897, 11.7859])
# Episode 393 terminated after 4 steps
# tensor([10.9919, 10.9068, 10.9307]) tensor([13.1742, 12.2273, 13.0554])
# Episode 394 terminated after 13 steps
# tensor([11.0151, 11.0745, 10.9392]) tensor([18.1100, -3.1857, 13.3173])
# Episode 395 terminated after 0 steps
# tensor([11.0619, 11.1496, 11.0186]) tensor([-9.8179, 26.0016,  5.8412])
# Episode 396 terminated after 0 steps
# tensor([11.1531, 11.0092, 10.9628]) tensor([ 3.3166, -5.3537, 19.4514])
# Episode 397 terminated after 3 steps
# tensor([11.0162, 11.1232, 11.1527]) tensor([14.5917,  5.4476,  6.2022])
# Episode 398 terminated after 0 steps
# tensor([11.0143, 11.0261, 10.8394]) tensor([ 6.4506, 14.0667,  8.0325])
# Episode 399 terminated after 0 steps
# tensor([10.8367, 10.9711, 10.9882]) tensor([-12.4155,  -0.1339,  11.9942])
# Episode 400 terminated after 1 steps
# Iteration 400 Loss: 2129793024.0 | V_Loss: 2129793024.0 | A_Loss: 2129793024.0
# tensor([10.8008, 10.8686, 10.8639]) tensor([ 6.2764,  8.1924, 27.9139])
# Episode 401 terminated after 8 steps
# tensor([10.8327, 10.7663, 10.9877]) tensor([17.4926, -1.1862, -3.8688])
# Episode 402 terminated after 2 steps
# tensor([10.7235, 10.6692, 10.7394]) tensor([ 6.7919, 20.3309,  2.6115])
# Episode 403 terminated after 0 steps
# tensor([10.7924, 10.7287, 10.6709]) tensor([-3.4751,  7.1741, 19.6022])
# Episode 404 terminated after 5 steps
# tensor([10.6425, 10.6597, 10.6698]) tensor([ 9.9098, 10.6410,  5.0554])
# Episode 405 terminated after 1 steps
# tensor([10.6259, 10.5717, 10.5576]) tensor([19.3334, 13.8904, 12.6982])
# Episode 406 terminated after 0 steps
# tensor([10.6063, 10.5389, 10.5997]) tensor([-5.6099, 10.7333,  4.7691])
# Episode 407 terminated after 0 steps
# tensor([10.5411, 10.5211, 10.5727]) tensor([-3.6781, -4.1433, 11.2056])
# Episode 408 terminated after 1 steps
# tensor([10.5195, 10.5018, 10.5758]) tensor([15.0327,  0.8010, -5.8995])
# Episode 409 terminated after 10 steps
# tensor([10.4843, 10.4994, 10.5136]) tensor([3.4690, 4.1323, 2.1508])
# Episode 410 terminated after 6 steps
# tensor([10.4300, 10.4526, 10.4737]) tensor([16.3330, 17.9889,  0.4363])
# Episode 411 terminated after 3 steps
# tensor([10.4348, 10.4344, 10.4140]) tensor([21.2608, 16.2363, -0.3907])
# Episode 412 terminated after 12 steps
# tensor([10.4034, 10.4196, 10.4552]) tensor([ 4.6746,  3.1777, 23.9465])
# Episode 413 terminated after 0 steps
# tensor([10.3872, 10.3985, 10.3618]) tensor([ 7.7016, 11.2442, 15.6627])
# Episode 414 terminated after 5 steps
# tensor([10.4015, 10.3440, 10.3467]) tensor([ 15.0263,   7.5366, -20.0611])
# Episode 415 terminated after 7 steps
# tensor([10.3406, 10.3524, 10.3690]) tensor([14.1000,  1.8451,  9.8849])
# Episode 416 terminated after 1 steps
# tensor([10.2784, 10.3524, 10.3153]) tensor([ 5.2798,  3.7325, 18.9078])
# Episode 417 terminated after 0 steps
# tensor([10.3017, 10.2903, 10.2793]) tensor([12.6041, 14.0435, 15.2458])
# Episode 418 terminated after 3 steps
# tensor([10.3077, 10.2940, 10.2967]) tensor([ 4.8460, 12.5036, 15.7629])
# Episode 419 terminated after 4 steps
# tensor([10.2858, 10.2805, 10.2764]) tensor([19.1757, -1.8421,  4.1169])
# Episode 420 terminated after 3 steps
# tensor([10.2703, 10.2663, 10.2797]) tensor([-18.0526,  16.9579,   6.7657])
# Episode 421 terminated after 11 steps
# tensor([10.2871, 10.2521, 10.2650]) tensor([ 12.7314, -10.8546,  35.5950])
# Episode 422 terminated after 0 steps
# tensor([10.2450, 10.2340, 10.2581]) tensor([19.3966, 10.1680,  5.2227])
# Episode 423 terminated after 7 steps
# tensor([10.2565, 10.2410, 10.2404]) tensor([-6.1652, 21.9607, -3.2586])
# Episode 424 terminated after 8 steps
# tensor([10.2240, 10.2182, 10.2398]) tensor([29.6663, 16.5533,  8.2756])
# Episode 425 terminated after 6 steps
# tensor([10.2191, 10.2352, 10.2164]) tensor([20.6737, 31.9929,  0.2329])
# Episode 426 terminated after 0 steps
# tensor([10.2157, 10.2147, 10.2100]) tensor([-0.9579, 10.5850,  0.0418])
# Episode 427 terminated after 1 steps
# tensor([10.2211, 10.2153, 10.2283]) tensor([23.8068,  7.0805, -0.1171])
# Episode 428 terminated after 3 steps
# tensor([10.2207, 10.2112, 10.2187]) tensor([25.3541,  7.4267, -0.2437])
# Episode 429 terminated after 5 steps
# tensor([10.2144, 10.2112, 10.2125]) tensor([16.8363, 14.3388, 19.3053])
# Episode 430 terminated after 12 steps
# tensor([10.2096, 10.2092, 10.2014]) tensor([ 5.8321,  4.7803, 12.1222])
# Episode 431 terminated after 4 steps
# tensor([10.2106, 10.2072, 10.2198]) tensor([14.0368, 20.9213, 12.6999])
# Episode 432 terminated after 4 steps
# tensor([10.2125, 10.2026, 10.2063]) tensor([ 3.3891, 22.3322, 10.6562])
# Episode 433 terminated after 4 steps
# tensor([10.2091, 10.2107, 10.2166]) tensor([ 3.4515, 12.6733, 26.2725])
# Episode 434 terminated after 9 steps
# tensor([10.2133, 10.2100, 10.2003]) tensor([13.7414,  3.8575,  8.2039])
# Episode 435 terminated after 5 steps
# tensor([10.1988, 10.1963, 10.1938]) tensor([ 9.2322, 10.5290, 21.9537])
# Episode 436 terminated after 21 steps
# tensor([10.1959, 10.2089, 10.1980]) tensor([-3.0891, 11.5154,  8.3846])
# Episode 437 terminated after 18 steps
# tensor([10.2045, 10.2023, 10.2014]) tensor([ 7.5125, 17.4535,  1.6006])
# Episode 438 terminated after 0 steps
# tensor([10.1947, 10.2073, 10.1881]) tensor([25.3448,  6.5148,  6.3096])
# Episode 439 terminated after 6 steps
# tensor([10.2015, 10.2040, 10.1939]) tensor([-2.8916, 13.5207, 10.2125])
# Episode 440 terminated after 3 steps
# tensor([10.2008, 10.2106, 10.1951]) tensor([22.4385, 19.5204,  1.7506])
# Episode 441 terminated after 3 steps
# tensor([10.1977, 10.1895, 10.1941]) tensor([-4.6321, 10.9983, -7.9717])
# Episode 442 terminated after 1 steps
# tensor([10.1920, 10.1920, 10.1950]) tensor([-8.0567,  9.1485, 21.7017])
# Episode 443 terminated after 5 steps
# tensor([10.1968, 10.2089, 10.1930]) tensor([ 5.5836, -1.7983, 23.9482])
# Episode 444 terminated after 8 steps
# tensor([10.1962, 10.1922, 10.1929]) tensor([10.5341, 21.1383, 15.2702])
# Episode 445 terminated after 1 steps
# tensor([10.1936, 10.1903, 10.1990]) tensor([ 4.6166, -2.1471,  6.5542])
# Episode 446 terminated after 4 steps
# tensor([10.1993, 10.2046, 10.1905]) tensor([ -5.8132,  19.8828, -12.8286])
# Episode 447 terminated after 2 steps
# tensor([10.1793, 10.2058, 10.1892]) tensor([12.1166, 18.8823,  8.3095])
# Episode 448 terminated after 3 steps
# tensor([10.1848, 10.1798, 10.1842]) tensor([-1.5647, 12.9088, 20.1945])
# Episode 449 terminated after 3 steps
# tensor([10.1908, 10.1899, 10.1808]) tensor([10.8820,  6.4853, 17.5192])
# Episode 450 terminated after 3 steps
# tensor([10.1875, 10.1964, 10.1965]) tensor([16.9893, 14.8714,  0.1504])
# Episode 451 terminated after 0 steps
# tensor([10.1957, 10.1794, 10.1829]) tensor([ 2.5805, 14.8098, -3.2381])
# Episode 452 terminated after 0 steps
# tensor([10.1960, 10.1820, 10.1826]) tensor([13.6006,  6.9975,  0.2985])
# Episode 453 terminated after 3 steps
# tensor([10.1748, 10.1902, 10.1754]) tensor([-1.9230, 18.1046, 17.4493])
# Episode 454 terminated after 2 steps
# tensor([10.1782, 10.1708, 10.1760]) tensor([-5.3390, 18.7015,  3.1342])
# Episode 455 terminated after 15 steps
# tensor([10.1679, 10.1835, 10.1685]) tensor([ 9.8347,  6.2271, 19.8461])
# Episode 456 terminated after 1 steps
# ...
# Episode 800 terminated after 6 steps
# Iteration 0.0 to 800. Total Steps = 0. Total stations selected = 26700(APs + LTEs)
#
# APs were selected 7007 times across 4878 steps. In 780 steps we had disconnection
# Only 5134 APs didn´t got negative reward(user connected)
# --> 72.84% of APs selected randomly | 27.16% selected by the NN as best action
# --> 0.00% of disconnections are from random actions | 100.00% from best actions
#
# LTE were selected 19693 times across 8399 steps
# --> 97.66% selected randomly | 2.34% selected by the NN as best action
#
# -----------------------------------------------------------------
# Iteration 800 Loss: 474364768.0 | V_Loss: 474364768.0 | A_Loss: 474364768.0
# tensor([10.1358, 10.1355, 10.1370]) tensor([15.3253, 10.8541, -1.4339])
# Episode 801 terminated after 1 steps
# tensor([10.1352, 10.1374, 10.1357]) tensor([-4.3369, 20.7989,  2.1149])
# Episode 802 terminated after 0 steps
# tensor([10.1368, 10.1371, 10.1351]) tensor([ 0.2844,  9.6332, 16.7353])
# Episode 803 terminated after 0 steps
# tensor([10.1354, 10.1366, 10.1359]) tensor([22.8163, 29.4918, -5.4603])
# Episode 804 terminated after 1 steps
# tensor([10.1350, 10.1366, 10.1360]) tensor([26.4274, 22.6000, 15.8032])
# Episode 805 terminated after 0 steps
# tensor([10.1350, 10.1368, 10.1355]) tensor([21.3023, -3.1739, 36.1236])
# Episode 806 terminated after 0 steps
# tensor([10.1358, 10.1355, 10.1357]) tensor([ 9.9735,  0.5450, 13.6491])
# Episode 807 terminated after 1 steps
# tensor([10.1359, 10.1356, 10.1360]) tensor([-5.5772,  8.1932, 17.8278])
# Episode 808 terminated after 0 steps
# tensor([10.1360, 10.1353, 10.1353]) tensor([24.3579, 18.3970, 10.1574])
# Episode 809 terminated after 0 steps
# tensor([10.1357, 10.1354, 10.1357]) tensor([26.7216,  4.1971, 13.8257])
# Episode 810 terminated after 0 steps
# tensor([10.1354, 10.1358, 10.1360]) tensor([10.3477, 10.4558, 13.7921])
# Episode 811 terminated after 4 steps
# tensor([10.1364, 10.1357, 10.1365]) tensor([ 7.0026,  3.4111, -3.7079])
# Episode 812 terminated after 4 steps
# tensor([10.1358, 10.1369, 10.1358]) tensor([ 7.0312, 18.6855, 18.1672])
# Episode 813 terminated after 0 steps
# tensor([10.1361, 10.1354, 10.1366]) tensor([-12.4883,   0.4301,  12.4867])
# Episode 814 terminated after 5 steps
# tensor([10.1368, 10.1372, 10.1367]) tensor([-9.2827, -0.8481, 17.1652])
# Episode 815 terminated after 3 steps
# tensor([10.1368, 10.1363, 10.1369]) tensor([-6.6116, -0.3529, 21.3055])
# Episode 816 terminated after 1 steps
# tensor([10.1359, 10.1358, 10.1370]) tensor([-1.7059,  4.6277, -1.7278])
# Episode 817 terminated after 1 steps
# tensor([10.1363, 10.1364, 10.1369]) tensor([10.6743, 17.7676,  4.3766])
# Episode 818 terminated after 4 steps
# tensor([10.1364, 10.1364, 10.1360]) tensor([ 3.3866, 20.1255, 10.2159])
# Episode 819 terminated after 0 steps
# tensor([10.1366, 10.1362, 10.1364]) tensor([ 3.9671, 10.8626, 19.4624])
# Episode 820 terminated after 1 steps
# tensor([10.1360, 10.1359, 10.1358]) tensor([-13.4978,  -5.0419,   4.5705])
# Episode 821 terminated after 0 steps
# tensor([10.1372, 10.1371, 10.1357]) tensor([14.9670, 40.9084, 21.9494])
# Episode 822 terminated after 0 steps
# tensor([10.1351, 10.1364, 10.1380]) tensor([12.0125, -0.2837,  0.7909])
# Episode 823 terminated after 3 steps
# tensor([10.1370, 10.1375, 10.1362]) tensor([15.8881, 12.0080, 10.5259])
# Episode 824 terminated after 4 steps
# tensor([10.1365, 10.1371, 10.1370]) tensor([15.3967,  7.2137, 12.4267])
# Episode 825 terminated after 0 steps
# tensor([10.1392, 10.1388, 10.1363]) tensor([14.2045, 31.9260,  6.8776])
# Episode 826 terminated after 0 steps
# tensor([10.1373, 10.1367, 10.1367]) tensor([ 6.6674, 13.2416, 17.8352])
# Episode 827 terminated after 0 steps
# tensor([10.1373, 10.1399, 10.1381]) tensor([-12.2910,   3.7793,  28.8539])
# Episode 828 terminated after 5 steps
# tensor([10.1372, 10.1388, 10.1375]) tensor([ 5.5154, 34.8447,  1.1709])
# Episode 829 terminated after 1 steps
# tensor([10.1388, 10.1372, 10.1379]) tensor([18.5134, 13.2870, 10.4419])
# Episode 830 terminated after 9 steps
# tensor([10.1388, 10.1375, 10.1383]) tensor([ 1.2765, 18.6466,  6.9920])
# Episode 831 terminated after 0 steps
# tensor([10.1387, 10.1409, 10.1395]) tensor([19.8847, 10.8240,  0.7232])
# Episode 832 terminated after 1 steps
# tensor([10.1377, 10.1387, 10.1386]) tensor([ 15.4568, -10.7908,  13.3876])
# Episode 833 terminated after 0 steps
# tensor([10.1415, 10.1392, 10.1390]) tensor([-0.9145, 16.9078, -3.6185])
# Episode 834 terminated after 0 steps
# tensor([10.1388, 10.1393, 10.1418]) tensor([ 9.6193, 13.1343, 23.7006])
# Episode 835 terminated after 2 steps
# tensor([10.1400, 10.1410, 10.1410]) tensor([-2.7905,  2.7007, 15.6067])
# Episode 836 terminated after 1 steps
# tensor([10.1402, 10.1393, 10.1412]) tensor([ 6.7027, 15.1919, 14.3739])
# Episode 837 terminated after 0 steps
# tensor([10.1405, 10.1409, 10.1422]) tensor([ 6.1291, -1.9918, 13.0779])
# Episode 838 terminated after 8 steps
# tensor([10.1401, 10.1430, 10.1399]) tensor([-1.0562, 17.8512,  6.5934])
# Episode 839 terminated after 1 steps
# tensor([10.1444, 10.1414, 10.1432]) tensor([24.8915, 32.9577, 26.5973])
# Episode 840 terminated after 0 steps
# tensor([10.1417, 10.1409, 10.1402]) tensor([12.6291, 21.9126,  5.6065])
# Episode 841 terminated after 1 steps
# tensor([10.1422, 10.1421, 10.1437]) tensor([36.2057, -3.0486, -1.2319])
# Episode 842 terminated after 1 steps
# tensor([10.1407, 10.1434, 10.1414]) tensor([ 3.7067, 10.3697, 14.5555])
# Episode 843 terminated after 12 steps
# tensor([10.1428, 10.1431, 10.1419]) tensor([ 7.9234, 30.4919,  3.5370])
# Episode 844 terminated after 1 steps
# tensor([10.1404, 10.1418, 10.1435]) tensor([ 7.0790,  2.2378, 11.1719])
# Episode 845 terminated after 1 steps
# tensor([10.1419, 10.1406, 10.1410]) tensor([ 13.7561, -12.6291,  31.3896])
# Episode 846 terminated after 6 steps
# tensor([10.1417, 10.1433, 10.1406]) tensor([ 5.5206, 20.7382,  7.1818])
# Episode 847 terminated after 2 steps
# tensor([10.1409, 10.1410, 10.1397]) tensor([ 7.9057, -3.9957,  7.3526])
# Episode 848 terminated after 1 steps
# tensor([10.1406, 10.1418, 10.1419]) tensor([20.3922, 11.2018,  8.2377])
# Episode 849 terminated after 1 steps
# tensor([10.1428, 10.1436, 10.1425]) tensor([ 5.7062, 20.7592, -5.7871])
# Episode 850 terminated after 1 steps
# tensor([10.1404, 10.1444, 10.1413]) tensor([17.0821, 10.5111, -1.0665])
# Episode 851 terminated after 0 steps
# tensor([10.1443, 10.1417, 10.1434]) tensor([24.2701, 19.4450, -7.7190])
# Episode 852 terminated after 3 steps
# tensor([10.1412, 10.1425, 10.1420]) tensor([17.3294, 12.5003,  1.1132])
# Episode 853 terminated after 5 steps
# tensor([10.1415, 10.1438, 10.1437]) tensor([19.6537, 23.2000,  6.7258])
# Episode 854 terminated after 1 steps
# tensor([10.1423, 10.1457, 10.1432]) tensor([11.2237,  7.7833, 15.8611])
# Episode 855 terminated after 4 steps
# tensor([10.1431, 10.1384, 10.1432]) tensor([ 3.8406, 14.4569, 12.1468])
# Episode 856 terminated after 0 steps
# tensor([10.1465, 10.1392, 10.1417]) tensor([-4.3501, 12.2762, -4.2524])
# Episode 857 terminated after 3 steps
# tensor([10.1464, 10.1422, 10.1424]) tensor([ 17.4901, -13.6565,  22.0964])
# Episode 858 terminated after 0 steps
# tensor([10.1449, 10.1462, 10.1437]) tensor([-4.1659, 23.7636,  0.7671])
# Episode 859 terminated after 0 steps
# tensor([10.1437, 10.1463, 10.1432]) tensor([10.6712,  6.0897, 32.3580])
# Episode 860 terminated after 7 steps
# tensor([10.1447, 10.1424, 10.1458]) tensor([10.8660, 10.3732, -4.6700])
# Episode 861 terminated after 0 steps
# tensor([10.1448, 10.1443, 10.1431]) tensor([ 8.6349, 30.6526, -0.2135])
# Episode 862 terminated after 3 steps
# tensor([10.1481, 10.1451, 10.1441]) tensor([ 9.0797, 21.1064, 19.4827])
# Episode 863 terminated after 0 steps
# tensor([10.1432, 10.1456, 10.1443]) tensor([13.1313,  8.9112, -0.8203])
# Episode 864 terminated after 0 steps
# tensor([10.1472, 10.1450, 10.1459]) tensor([20.9866,  4.3472, 11.7798])
# Episode 865 terminated after 0 steps
# tensor([10.1442, 10.1497, 10.1508]) tensor([10.1798, 13.4212,  4.1771])
# Episode 866 terminated after 4 steps
# tensor([10.1493, 10.1513, 10.1488]) tensor([11.1583, 12.0335, -6.6189])
# Episode 867 terminated after 3 steps
# tensor([10.1496, 10.1461, 10.1489]) tensor([16.6808, 10.5548, 23.9653])
# Episode 868 terminated after 1 steps
# tensor([10.1480, 10.1530, 10.1481]) tensor([12.7468,  6.8642, 14.1413])
# Episode 869 terminated after 3 steps
# tensor([10.1501, 10.1491, 10.1553]) tensor([18.0825, -1.0506, 13.4834])
# Episode 870 terminated after 1 steps
# tensor([10.1441, 10.1577, 10.1607]) tensor([29.0840, 12.5603,  9.0710])
# Episode 871 terminated after 2 steps
# tensor([10.1528, 10.1559, 10.1567]) tensor([24.7485, 11.2649, 15.1149])
# Episode 872 terminated after 2 steps
# tensor([10.1610, 10.1571, 10.1544]) tensor([-12.4232,   7.6146,  28.1615])
# Episode 873 terminated after 1 steps
# tensor([10.1545, 10.1605, 10.1572]) tensor([-0.8821, 25.3633, 25.4599])
# Episode 874 terminated after 3 steps
# tensor([10.1542, 10.1615, 10.1585]) tensor([ 1.3475, 17.6969, -8.4172])
# Episode 875 terminated after 1 steps
# tensor([10.1655, 10.1571, 10.1618]) tensor([ 4.6923, 10.7571, 13.8507])
# Episode 876 terminated after 0 steps
# tensor([10.1559, 10.1592, 10.1540]) tensor([ 8.5513, 10.0330, 15.4230])
# Episode 877 terminated after 5 steps
# tensor([10.1578, 10.1635, 10.1579]) tensor([ 0.0739, 14.9462, 16.8030])
# Episode 878 terminated after 0 steps
# tensor([10.1603, 10.1552, 10.1557]) tensor([ 2.9696, 17.2911, 11.8307])
# Episode 879 terminated after 0 steps
# tensor([10.1546, 10.1570, 10.1553]) tensor([-12.5961,  35.0411,  13.9931])
# Episode 880 terminated after 0 steps
# tensor([10.1571, 10.1532, 10.1525]) tensor([18.0541,  7.9212, 13.0246])
# Episode 881 terminated after 0 steps
# tensor([10.1561, 10.1583, 10.1625]) tensor([ 3.5088, 24.0248,  2.4216])
# Episode 882 terminated after 1 steps
# tensor([10.1640, 10.1612, 10.1533]) tensor([26.7011, 12.0230, -1.8968])
# Episode 883 terminated after 0 steps
# tensor([10.1591, 10.1597, 10.1558]) tensor([23.7630, 22.6772, -0.9026])
# Episode 884 terminated after 1 steps
# tensor([10.1553, 10.1553, 10.1554]) tensor([ 5.4826, 14.0452, 23.7275])
# Episode 885 terminated after 1 steps
# tensor([10.1577, 10.1566, 10.1578]) tensor([ 9.9826, 17.4778, -4.1530])
# Episode 886 terminated after 0 steps
# tensor([10.1662, 10.1668, 10.1675]) tensor([-15.7962,   9.8440,   1.4674])
# Episode 887 terminated after 0 steps
# tensor([10.1576, 10.1588, 10.1570]) tensor([13.1365,  5.0713,  7.3201])
# Episode 888 terminated after 1 steps
# tensor([10.1576, 10.1602, 10.1597]) tensor([13.7142,  4.5923, 19.6084])
# Episode 889 terminated after 2 steps
# tensor([10.1545, 10.1571, 10.1597]) tensor([-11.4335,   4.2833,   2.6578])
# Episode 890 terminated after 1 steps
# tensor([10.1586, 10.1565, 10.1587]) tensor([12.6599, 25.9090, 21.9752])
# Episode 891 terminated after 2 steps
# tensor([10.1526, 10.1557, 10.1551]) tensor([33.0620, 15.4251, 12.8906])
# Episode 892 terminated after 2 steps
# tensor([10.1550, 10.1556, 10.1544]) tensor([ 2.1502,  3.2788, 22.0338])
# Episode 893 terminated after 1 steps
# tensor([10.1480, 10.1538, 10.1555]) tensor([17.7447, 15.8927, 18.6810])
# Episode 894 terminated after 11 steps
# tensor([10.1518, 10.1514, 10.1517]) tensor([28.5180,  3.1026, -1.3407])
# Episode 895 terminated after 0 steps
# tensor([10.1466, 10.1510, 10.1557]) tensor([12.8089,  6.6618, 17.1426])
# Episode 896 terminated after 0 steps
# tensor([10.1500, 10.1587, 10.1495]) tensor([11.7327, -3.1740, -0.4457])
# Episode 897 terminated after 1 steps
# tensor([10.1516, 10.1537, 10.1562]) tensor([ 1.4239, 27.3572, 14.9770])
# Episode 898 terminated after 0 steps
# tensor([10.1535, 10.1486, 10.1488]) tensor([1.2651, 1.7611, 8.4633])
# Episode 899 terminated after 0 steps
# tensor([10.1532, 10.1506, 10.1494]) tensor([ 5.1743, 19.2002, 18.4625])
# Episode 900 terminated after 1 steps
# tensor([10.1531, 10.1528, 10.1513]) tensor([ 6.4388,  8.9331, 10.8513])
# Episode 901 terminated after 0 steps
# tensor([10.1492, 10.1505, 10.1500]) tensor([ 7.4166, 15.8120,  5.6917])
# Episode 902 terminated after 0 steps
# tensor([10.1511, 10.1518, 10.1512]) tensor([ 2.5359, 19.3821,  2.3611])
# Episode 903 terminated after 4 steps
# tensor([10.1493, 10.1554, 10.1530]) tensor([11.2748, 12.9456, 25.9950])
# Episode 904 terminated after 5 steps
# tensor([10.1524, 10.1506, 10.1477]) tensor([11.2930, -0.4401, 13.3694])
# Episode 905 terminated after 5 steps
# tensor([10.1607, 10.1535, 10.1627]) tensor([ 3.7369,  9.1809, 14.5278])
# Episode 906 terminated after 0 steps
# tensor([10.1528, 10.1560, 10.1497]) tensor([-3.8704, 11.6356, 20.3192])
# Episode 907 terminated after 0 steps
# tensor([10.1566, 10.1595, 10.1563]) tensor([11.1072, 14.8522, 17.3419])
# Episode 908 terminated after 0 steps
# tensor([10.1553, 10.1600, 10.1513]) tensor([ 8.4570,  0.5505, -2.8482])
# Episode 909 terminated after 1 steps
# tensor([10.1661, 10.1570, 10.1559]) tensor([19.4112, 18.9100, 18.4583])
# Episode 910 terminated after 0 steps
# tensor([10.1526, 10.1662, 10.1613]) tensor([-4.6707,  4.5887, -2.4633])
# Episode 911 terminated after 0 steps
# tensor([10.1677, 10.1667, 10.1586]) tensor([ 6.5061, 21.9511, -5.6472])
# Episode 912 terminated after 1 steps
# tensor([10.1651, 10.1542, 10.1538]) tensor([ 0.1687, 18.9972, 19.5539])
# Episode 913 terminated after 0 steps
# tensor([10.1618, 10.1615, 10.1604]) tensor([-1.6217,  5.1988, 11.5153])
# Episode 914 terminated after 0 steps
# tensor([10.1593, 10.1564, 10.1561]) tensor([ 1.6788, -4.6117, 27.9093])
# Episode 915 terminated after 1 steps
# tensor([10.1637, 10.1542, 10.1605]) tensor([-1.2016, 29.9399, 22.4010])
# Episode 916 terminated after 0 steps
# tensor([10.1554, 10.1573, 10.1655]) tensor([ 3.0367, 15.1138, 20.0400])
# Episode 917 terminated after 0 steps
# tensor([10.1573, 10.1655, 10.1593]) tensor([15.7900, 29.4357, 13.5283])
# Episode 918 terminated after 0 steps
# tensor([10.1623, 10.1584, 10.1611]) tensor([ 8.2796, 23.9562, 28.0520])
# Episode 919 terminated after 0 steps
# tensor([10.1611, 10.1688, 10.1600]) tensor([-24.3500,  19.4435,  12.8712])
# Episode 920 terminated after 1 steps
# tensor([10.1672, 10.1655, 10.1613]) tensor([11.5703, 19.4325,  7.8201])
# Episode 921 terminated after 1 steps
# tensor([10.1603, 10.1608, 10.1597]) tensor([12.5894,  2.2332,  7.8374])
# Episode 922 terminated after 2 steps
# tensor([10.1581, 10.1665, 10.1557]) tensor([ 4.9533, -2.6037,  4.5304])
# Episode 923 terminated after 0 steps
# tensor([10.1603, 10.1614, 10.1561]) tensor([ 6.3047, 21.1597, 17.7979])
# Episode 924 terminated after 0 steps
# tensor([10.1584, 10.1542, 10.1598]) tensor([19.4893, 21.5951, 29.3134])
# Episode 925 terminated after 0 steps
# tensor([10.1530, 10.1540, 10.1571]) tensor([-4.8387, 17.5483, 19.5896])
# Episode 926 terminated after 0 steps
# tensor([10.1563, 10.1532, 10.1617]) tensor([-1.1874, 14.5633, 12.4242])
# Episode 927 terminated after 5 steps
# tensor([10.1539, 10.1601, 10.1574]) tensor([ 1.9964, -3.7060, 13.9484])
# Episode 928 terminated after 0 steps
# tensor([10.1451, 10.1620, 10.1550]) tensor([ 8.2645, 22.5962,  4.8609])
# Episode 929 terminated after 2 steps
# tensor([10.1512, 10.1532, 10.1525]) tensor([13.6909,  1.2273, 20.6367])
# Episode 930 terminated after 2 steps
# tensor([10.1565, 10.1520, 10.1499]) tensor([10.6473,  7.7777, 16.3944])
# Episode 931 terminated after 0 steps
# tensor([10.1561, 10.1488, 10.1538]) tensor([15.0033, 14.2265, 11.4380])
# Episode 932 terminated after 1 steps
# tensor([10.1533, 10.1552, 10.1498]) tensor([14.6174, 15.2381, -8.6936])
# Episode 933 terminated after 1 steps
# tensor([10.1531, 10.1576, 10.1515]) tensor([ 8.4708, 17.0281, -0.1783])
# Episode 934 terminated after 2 steps
# tensor([10.1497, 10.1517, 10.1524]) tensor([ 3.0574,  0.4293, -4.6752])
# tensor([10.1527, 10.1556, 10.1499]) tensor([ 6.3717, -5.7860, 24.5654])
# Episode 935 terminated after 6 steps
# tensor([10.1564, 10.1495, 10.1521]) tensor([ 6.2732, 23.4976,  1.0317])
# Episode 936 terminated after 1 steps
# tensor([10.1531, 10.1549, 10.1485]) tensor([20.7103,  4.5987, 10.2988])
# Episode 937 terminated after 0 steps
# tensor([10.1502, 10.1626, 10.1548]) tensor([-7.0686, 13.2250, 35.8688])
# Episode 938 terminated after 0 steps
# tensor([10.1537, 10.1485, 10.1515]) tensor([ 2.0068,  7.1176, -2.3811])
# Episode 939 terminated after 1 steps

# %%
plt.figure(figsize=(8, 5)) 

plt.plot(loss_data, label="Loss", color="blue", linewidth=2, marker="o", markersize=4)

plt.ylim(np.min(loss_data) * 0.9, np.max(loss_data) * 1.1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Time")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)

min_idx = np.argmin(loss_data)
max_idx = np.argmax(loss_data)

plt.scatter([min_idx, max_idx], [loss_data[min_idx], loss_data[max_idx]], color="red", zorder=3)
plt.annotate(f"Min: {loss_data[min_idx]:.2f}", (min_idx, loss_data[min_idx]), 
             textcoords="offset points", xytext=(5, -10), ha="left", color="red")
plt.annotate(f"Max: {loss_data[max_idx]:.2f}", (max_idx, loss_data[max_idx]), 
             textcoords="offset points", xytext=(5, 10), ha="left", color="red")

plt.show()

# %%
steps = []
rewards = [[] for _ in range(n_users)]

with open('rewards.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        steps.append(int(row["step"]) + 1)
        for j in range(n_users):
            rewards[j].append(float(row[f"reward_{j+1}"]))

plt.figure(figsize=(12, 8))

agents_plotted = n_users
for j in range(agents_plotted):
    plt.plot(steps, rewards[j], label=f"Reward {j+1}")
    
plt.xlabel("Steps")
plt.ylabel("Reward")
plt.title("Reward per step for Each Agent")
plt.legend()
plt.grid()
plt.show()

# %%
episode_rewards = np.array(episode_rewards)

# Calculate the average reward across all agents for each episode
average_rewards = np.mean(episode_rewards, axis=1)

plt.figure(figsize=(12, 8))

# Plot the average reward per episode across all agents
plt.plot(range(episode_rewards.shape[0]), average_rewards, label="Average Reward")

plt.xlabel("Episode")
plt.ylabel("Average Reward")
plt.title("Average Reward per Episode Across All Agents")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Reward for each agent

# %%
steps = []
rewards = [[] for _ in range(n_users)]  # Adjusting to 20 agents

# Read rewards data from the CSV file
with open('rewards.csv', 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        steps.append(int(row["step"]) + 1)
        for j in range(n_users):  # Loop over 20 agents
            rewards[j].append(float(row[f"reward_{j+1}"]))

# Create a 5x4 grid of subplots for 20 agents
fig, axes = plt.subplots(5, 4, figsize=(15, 15))
fig.tight_layout(pad=5.0)  # Add space between plots

# Flatten the 2D axes array to make it easier to loop through
axes = axes.flatten()

# Plot rewards for each agent in its own subplot
for j in range(n_users):
    ax = axes[j]
    ax.plot(steps, rewards[j])
    ax.set_title(f"Agent {j+1}")
    ax.set_xlabel("Steps")
    ax.set_ylabel("Reward")
    ax.grid(True)

plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.bar(range(len(last_rats)), last_rats, edgecolor='black')


plt.xlabel('Index')
plt.xticks(range(len(last_rats))) 
plt.ylabel('Value')
plt.title('Bar Plot of Rat Values')

# %%
plt.figure(figsize=(12, 6))

plt.bar(range(len(last_rats)), best_actions, edgecolor='black')
plt.xlabel('Index')
plt.xticks(range(len(best_actions))) 
plt.ylabel('Value')
plt.title('Oupput Values of the NN')

plt.show()

# %%
plt.plot(range(len(eps_list)),eps_list)
plt.ylabel('epsilon')
plt.show()
plt.close()
