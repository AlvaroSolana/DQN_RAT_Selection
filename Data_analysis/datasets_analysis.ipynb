# %%
import pandas as pd

cqi_df = pd.read_csv("cqi_distance.csv")
rssi_df = pd.read_csv("rssi_distance.csv")

# %%
print(cqi_df.columns)
# Out:
# Index(['Distance', 'CQI'], dtype='object')

# %%
plt.figure(figsize=(8, 5))

plt.scatter(cqi_df["Distance"], cqi_df["CQI"])

# Labels, title, and legend
plt.xlabel("Distance (m)")
plt.ylabel("CQI")
plt.title("CQI values")
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()
